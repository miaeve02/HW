# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/miaalfonso/Desktop/HW/Assignment2/Data_Plant.csv")
#/Data_Plant.csv Assignment2/Data_Plant.csv

# %%
#Problem 1
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7199 entries, 0 to 7198
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   39527.25     7199 non-null   float64
#  1   27.46636009  7198 non-null   float64
#  2   27.62891006  7198 non-null   float64
#  3   8.822265625  7199 non-null   float64
#  4   5.396483898  7199 non-null   float64
#  5   1691.651001  7199 non-null   float64
#  6   7.366691113  7199 non-null   float64
#  7   78.55264282  7199 non-null   float64
#  8   13.51465034  7199 non-null   float64
#  9   36.84375     7199 non-null   float64
#  10  49.53516006  7198 non-null   float64
#  11  89.08007813  7199 non-null   float64
#  12  92.59375     7199 non-null   float64
#  13  99.771492    7198 non-null   float64
#  14  8588.513672  7198 non-null   float64
#  15  60.45621872  7199 non-null   float64
#  16  45.68021011  7198 non-null   float64
#  17  3.066406012  7199 non-null   float64
# ...

# %%
df.head(10)
# Out:
#       39527.25  27.46636009  27.62891006  8.822265625  5.396483898  \
# 0  39527.25208    27.471821    27.566410     8.869142     5.396484
# 1  39527.25417    27.477289    27.539061     8.734374     5.404296
# 2  39527.25625    27.482759          NaN     8.734374     5.427734
# 3  39527.25833    27.488220    27.476561     8.756347     5.427734
# 4  39527.26042    27.493690    27.468750     8.756347     5.427734
# 5  39527.26250    27.499161    27.737310     8.822266     5.427734
# 6  39527.26458    27.503080    28.640631     9.648439     5.488281
# 7  39527.26667    27.496700    28.394529     9.537109     5.457031
# 8  39527.26875    27.490320    28.534180     9.191404     5.548828
# 9  39527.27083    27.483950    28.394529     9.466796     5.526855
#
#    1691.651001  7.366691113  78.55264282  13.51465034   36.84375  ...  \
# 0  1698.780029     7.370453    78.717918     13.69824  36.843750  ...
# 1  1703.457031     7.374215    78.399452     13.74219  36.843750  ...
# ...

# %%
df.describe()
# Out:
#            39527.25  27.46636009  27.62891006  8.822265625  5.396483898  \
# count   7199.000000  7198.000000  7198.000000  7199.000000  7199.000000
# mean   39534.750000    27.127295    27.953209     9.593198     6.395699
# std        4.329826     0.674680     0.698533     0.630545     0.952640
# min    39527.252080    24.231501    24.593750     7.673828     4.951172
# 25%    39531.001040    26.652867    27.507811     9.191404     5.640625
# 50%    39534.750000    27.109890    27.906250     9.570802     6.177734
# 75%    39538.498960    27.518567    28.394529     9.923826     6.958984
# max    39542.247920    47.017712    42.443359    17.277340    19.515141
#
#        1691.651001  7.366691113  78.55264282  13.51465034     36.84375  ...  \
# count  7199.000000  7199.000000  7199.000000  7199.000000  7199.000000  ...
# mean   1701.915367    11.555007    76.332696    18.356032    37.815861  ...
# std      99.738546     2.901431     3.595688     3.648891     1.768092  ...
# ...

# %%
df.shape
# Out:
# (7199, 27)

# %%
df.columns = df.columns.str.upper()

# %%
#Problem 2
df.isnull().sum().sum()
# Out:
# 11

# %%
df_mean = df.fillna(df.mean())

# %%
df_drop_dup = df.drop_duplicates()

# %%
#Problem 3
x_train, x_temp = train_test_split(df, test_size = 0.3, random_state=42)
#
x_val, x_test = train_test_split(x_temp, test_size=0.5, random_state=42)

# %%
print(len(x_train))
print(len(x_test))
print(len(x_val))
# Out:
# 5039
# 1080
# 1080

# %%
x_train.head()
# Out:
#          39527.25  27.46636009  27.62891006  8.822265625  5.396483898  \
# 1224  39529.80208    26.964970    28.027340    10.433590     7.169141
# 142   39527.54792    27.113880    28.703131     9.994142     7.411621
# 1490  39530.35625    26.465530    27.382811     9.050780     5.365234
# 7179  39542.20833    26.863079    27.906250     9.560548     5.616015
# 2663  39532.80000    27.377840    28.304689    10.111330     6.054688
#
#       1691.651001  7.366691113  78.55264282  13.51465034   36.84375  ...  \
# 1224  1716.454956    14.712780    73.926971    21.898439  37.857422  ...
# 142   1755.282959    16.069889    70.363358    22.386721  37.904301  ...
# 1490  1698.114990     7.595062    79.663452    12.304690  36.802731  ...
# 7179  1583.935059     8.373703    78.741470    11.320310  37.031250  ...
# 2663  1721.592041    10.786220    74.878487    18.582821  38.081249  ...
#
#       3.066406012  55.95146179  71.27528381  30.65937042  30.5925808  \
# ...

# %%
x_val.head()
# Out:
#          39527.25  27.46636009  27.62891006  8.822265625  5.396483898  \
# 6037  39539.82917    26.152800    26.984381     8.734374     6.316406
# 167   39527.60000    27.603710    28.335939    10.134760     6.261718
# 4761  39537.17083    26.595160    26.874220     8.318358     5.718750
# 5477  39538.66250    27.269621    28.394529    10.246090     6.632325
# 1744  39530.88542    27.041849    28.643749    10.111330     6.835938
#
#       1691.651001  7.366691113  78.55264282  13.51465034   36.84375  ...  \
# 6037  1564.453003     11.74887    75.086166    19.848440  36.843750  ...
# 167   1736.826050     12.48243    71.556641    20.703131  38.179691  ...
# 4761  1642.237061     10.89223    76.098084    18.564060  36.890629  ...
# 5477  1725.635010     12.97583    76.921127    21.222660  37.722660  ...
# 1744  1654.208984     13.61673    75.956062    21.222660  37.857422  ...
#
#       3.066406012  55.95146179  71.27528381  30.65937042  30.5925808  \
# ...

# %%
#Problem 4
scaler = StandardScaler().fit(x_train)

# %%
x_train
# Out:
#          39527.25  27.46636009  27.62891006  8.822265625  5.396483898  \
# 1224  39529.80208    26.964970    28.027340    10.433590     7.169141
# 142   39527.54792    27.113880    28.703131     9.994142     7.411621
# 1490  39530.35625    26.465530    27.382811     9.050780     5.365234
# 7179  39542.20833    26.863079    27.906250     9.560548     5.616015
# 2663  39532.80000    27.377840    28.304689    10.111330     6.054688
# ...           ...          ...          ...          ...          ...
# 3772  39535.11042    27.079130    28.121090     9.648439     6.031739
# 5191  39538.06667    27.545870    28.488279    10.464350     7.158204
# 5226  39538.13958    27.823280    28.855471    10.890620     5.826172
# 5390  39538.48125    27.786190    28.886721     9.009765     6.867188
# 860   39529.04375    27.736481    28.703131     9.789063     5.947266
#
#       1691.651001  7.366691113  78.55264282  13.51465034   36.84375  ...  \
# ...

# %%
df_scaled = scaler.transform(x_train)

# %%
df_scaled
# Out:
# array([[-1.15442835, -0.25071415,  0.12133967, ...,  0.57697576,
#         -0.49476244,  0.04567541],
#        [-1.67797257, -0.01209719,  1.12684229, ...,  0.84145414,
#          0.82185437,  0.10665686],
#        [-1.02571854, -1.0510248 , -0.83764937, ..., -1.08984874,
#          0.1652601 ,  0.05441997],
#        ...,
#        [ 0.78201358,  1.12465872,  1.35350743, ..., -0.26873684,
#         -1.4699939 ,  0.01241281],
#        [ 0.86136879,  1.06522454,  1.400004  , ...,  1.15513541,
#          1.85535978,  0.04130954],
#        [-1.33055572,  0.98556941,  1.12684229, ..., -0.2195317 ,
#          0.14313475,  0.04780714]])

# %%
def log_transform(x):
    return np.log(x+1)

df_log = log_transform(df_scaled)
# Out:
# /var/folders/km/r41513gd0glcqg29cdttf5mm0000gn/T/ipykernel_6700/2685063011.py:2: RuntimeWarning: invalid value encountered in log
#   return np.log(x+1)

# %%
df_log
# Out:
# array([[        nan, -0.28863473,  0.1145241 , ...,  0.45550894,
#         -0.68272654,  0.04466301],
#        [        nan, -0.01217096,  0.75463839, ...,  0.61055555,
#          0.59985487,  0.10134363],
#        [        nan,         nan, -1.8179969 , ...,         nan,
#          0.15294432,  0.05299083],
#        ...,
#        [ 0.57774395,  0.75361119,  0.85590674, ..., -0.31298188,
#                 nan,  0.0123364 ],
#        [ 0.62131213,  0.72523896,  0.8754704 , ...,  0.76785356,
#          1.04919785,  0.04047909],
#        [        nan,  0.68590573,  0.75463839, ..., -0.24786115,
#          0.13377427,  0.04669955]])
